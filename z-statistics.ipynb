# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy 
import pandas as pd
import scipy.stats

# %%
data = pd.read_csv("./encoded_data.csv")
data.head()
# Out:
#    Unnamed: 0              Name  Age  Gender  MWP_BC  MQB_BC  MWP_AC  MQB_AC  \
# 0           0            Aarjav    0       1     0.0       0     0.0       0
# 1           1            Aashna    0       0    20.0      20    90.0     200
# 2           2     Aatman Vaidya    0       1    30.0       0    70.0     900
# 3           3           Aayushi    0       0    50.0      50    95.0    1000
# 4           4  Aayushi Sameriya    0       0    70.0       0   100.0       1
#
#    Type  Brand
# 0     0      3
# 1     0      3
# 2     0      0
# 3     1      3
# 4     0      3

# %%
data.describe()
# Out:
#        Unnamed: 0        Age     Gender      MWP_BC       MQB_BC       MWP_AC  \
# count   79.000000  79.000000  79.000000   79.000000    79.000000    79.000000
# mean    39.000000   0.443038   0.594937   42.069620   100.303797    85.943038
# std     22.949219   0.873350   0.494041   24.929739   265.012982   123.434037
# min      0.000000   0.000000   0.000000    0.000000     0.000000     0.000000
# 25%     19.500000   0.000000   0.000000   25.000000     1.000000    37.500000
# 50%     39.000000   0.000000   1.000000   40.000000    30.000000    50.000000
# 75%     58.500000   0.000000   1.000000   50.000000    75.000000   100.000000
# max     78.000000   3.000000   1.000000  100.000000  2000.000000  1000.000000
#
#              MQB_AC       Type      Brand
# count     79.000000  79.000000  79.000000
# mean     958.708861   0.658228   3.810127
# std     2593.417190   0.860621   1.641419
# min        0.000000   0.000000   0.000000
# 25%       85.000000   0.000000   3.000000
# ...

# %%
SE=np.std(data.MWP_BC)/np.sqrt(np.size(data.MWP_BC))

# %%
def p_value():
    z=(np.mean(data.MWP_AC)-np.mean(data.MWP_BC))/SE
    print("Z value= ",z)
    p=scipy.stats.norm.sf(abs(z))
    print("p_value= ",p)

# %%
p_value()
# Out:
# Z value=  15.742131127205779
# p_value=  3.888970538024388e-56

# %% [markdown]
# Z-value tells us how many std errors is the observed value from the expected value. The z-value is very high which tells us that the observed value is very far from the expected value and as a result we get a low p-value.Hence, we reject the null hypothesis that say t
